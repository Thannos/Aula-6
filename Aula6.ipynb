# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.linspace(10.0, 0.0, num=2))
plt.plot(np.linspace(0.0, 9.0, num=6))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
a=np.array([[3,1],[1,2]])
b=np.array([9,8])
x=np.linalg.solve(a,b)
print(x)
#array([2., 3.])
np.allclose(np.dot(a,x),b)
